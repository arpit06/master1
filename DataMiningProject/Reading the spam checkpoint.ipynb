# %%
import pandas as pd

# %%
spamreader = pd.read_csv('spam_checkpoints_clear.csv', header=None, usecols=[0,8])

# %%
pd.DataFrame.from_csv('spam_checkpoints_clear.csv')
# Out:
#                                                     B1  S3   S2 Unnamed: 4  \
# air.FUNCOM.CaptionCamera
# air.FUNCOM.WinterLock                               S2  S3   S2         S3
# air.com.Slot                                        S1  S8   S2        S1
# air.com.zubawing.PokeChampionLite                   S6  S6   S6        NaN
# air.talkingDragon                                   S6  C1   C2         S6
# alice.superman.golocker                             S9  S9   S9        NaN
# alpmob.pokemon                                      S2  S3   S3         S2
# app12384.vinebre                                    S7  S8   S8         U2
# appinventor.ai_DeAnnaBeth1964.VolumeBooster         S7  S8   C1         C2
# appinventor.ai_idigitalbox.Communication            S1  S1   U4        NaN
# appinventor.ai_monastucecom.JoyofBaking             S1  S2   S3         S7
# appinventor.ai_monastucecom.Top20InterviewQuest...  S1  S2   S3         S7
# ...
